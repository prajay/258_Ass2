# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %%
with open('train.tsv') as f:
    data = pd.read_csv(f, sep='\t')

# %%
data
# Out:
#          train_id                                     name  item_condition_id  \
# 0               0      MLB Cincinnati Reds T Shirt Size XL                  3
# 1               1         Razer BlackWidow Chroma Keyboard                  3
# 2               2                           AVA-VIV Blouse                  1
# 3               3                    Leather Horse Statues                  1
# 4               4                     24K GOLD plated rose                  1
# 5               5         Bundled items requested for Ruie                  3
# 6               6       Acacia pacific tides santorini top                  3
# 7               7     Girls cheer and tumbling bundle of 7                  3
# 8               8                    Girls Nike Pro shorts                  3
# 9               9   Porcelain clown doll checker pants VTG                  3
# 10             10                          Smashbox primer                  2
# ...

# %%
len(data)
# Out:
# 1482536

# %%
len(data['category_name'].unique())
# Out:
# 1288

# %%
len(data['brand_name'].unique())
# Out:
# 4810

# %%
data['brand_name'] = data['brand_name'].fillna("NO")
data['category_name'] = data['category_name'].fillna("NA")

# %%
data['basic_category'] = data['category_name'].apply(lambda x : x.split('/')[0])

# %%
top_brands = data['brand_name'].value_counts()[:51]
top_brands = set(top_brands.index)
data['top_brand'] = data['brand_name'].apply(lambda x : x if x in top_brands else "NO")

# %%
len(data['item_condition_id'].unique())
# Out:
# 5

# %%
enc = OneHotEncoder()
enc.fit(data['item_condition_id'].values.reshape(-1,1))
enc.n_values_
# Out:
# array([6])

# %%
enc.feature_indices_
# Out:
# array([0, 6])

# %%
one_hot_condition_id = enc.transform(data['item_condition_id'].values.reshape(-1,1)).toarray()

# %%
enc = OneHotEncoder()
enc.fit(data['top_brand'].values.reshape(-1,1))
one_hot_top_brand = enc.transform(data['top_brand'].values.reshape(-1,1)).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-dfc6ac7b30f6> in <module>()
#       1 enc = OneHotEncoder()
# ----> 2 enc.fit(data['top_brand'].values.reshape(-1,1))
#       3 one_hot_top_brand = enc.transform(data['top_brand'].values.reshape(-1,1)).toarray()
#
# ~/.conda/envs/anirudh_tf/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#    1954         self
#    1955         """
# -> 1956         self.fit_transform(X)
#    1957         return self
#    1958
#
# ~/.conda/envs/anirudh_tf/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# ...

# %%
data['top_brand']
# Out:
# 0                         NA
# 1                         NA
# 2                         NA
# 3                         NA
# 4                         NA
# 5                         NA
# 6                         NA
# 7                         NA
# 8                       Nike
# 9                         NA
# 10                        NA
# 11         Victoria's Secret
# 12                        NA
# 13                        NA
# 14             UGG Australia
# 15                     Tarte
# 16                        NA
# 17                        NA
# 18                 Too Faced
# 19                        NA
# 20                        NA
# 21         Victoria's Secret
# 22                   Samsung
# 23                        NA
# 24                FOREVER 21
# 25                Air Jordan
# 26                     Apple
# 27                   LuLaRoe
# 28                FOREVER 21
# 29                 Hollister
#                  ...
# 1482505       The North Face
# ...

# %%
data['top_brand'].values.reshape(-1,1)
# Out:
# array([['NA'],
#        ['NA'],
#        ['NA'],
#        ...,
#        ['NA'],
#        ['NA'],
#        ['NA']], dtype=object)

# %%
# Out:
# 0                         NA
# 1                         NO
# 2                         NO
# 3                         NA
# 4                         NA
# 5                         NA
# 6                         NO
# 7                         NO
# 8                       Nike
# 9                         NA
# 10                        NO
# 11         Victoria's Secret
# 12                        NO
# 13                        NO
# 14             UGG Australia
# 15                     Tarte
# 16                        NO
# 17                        NA
# 18                 Too Faced
# 19                        NO
# 20                        NO
# 21         Victoria's Secret
# 22                   Samsung
# 23                        NA
# 24                FOREVER 21
# 25                Air Jordan
# 26                     Apple
# 27                   LuLaRoe
# 28                FOREVER 21
# 29                 Hollister
#                  ...
# 1482505       The North Face
# ...
